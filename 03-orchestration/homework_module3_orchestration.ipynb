# %% [markdown]
# ## Q2 RAG vs No RAG

# %%
```
INFO 2026-06-30T12:11:58.149048Z ❌ Response WITHOUT RAG (no retrieved context):
Kestra 1.1 introduced several exciting features that significantly enhanced its capabilities and user experience. Here are at least 5 major features with brief descriptions:

1.  **UI Redesign and Enhanced Navigation:**
    *   **Description:** This was a comprehensive overhaul of the Kestra user interface, focusing on improved aesthetics, readability, and a more intuitive navigation system. Key changes included a redesigned sidebar for easier access to different sections (flows, templates, executions, etc.), a more modern look and feel, and better organization of information, making it quicker for users to find what they need and manage their workflows.

2.  **API Enhancements and New API Endpoints:**
    *   **Description:** Kestra 1.1 significantly expanded its API capabilities, introducing new endpoints and improving existing ones. This allowed for greater programmatic control over Kestra instances, enabling users to more easily integrate Kestra with other systems, automate deployment and management of flows, retrieve detailed execution logs, and manage namespaces and users directly through API calls. This was crucial for larger organizations and CI/CD pipelines.

3.  **New Plugin for Databricks Integration (Databricks Plugin):**
    *   **Description:** A major addition was the dedicated plugin for deep integration with Databricks. This plugin provided a set of tasks specifically designed to interact with Databricks, such as running notebooks, submitting jobs, and managing clusters directly from Kestra flows. This enabled users to orchestrate their data transformation and machine learning workflows on Databricks seamlessly within Kestra, leveraging Kestra's scheduling, monitoring, and error handling capabilities.

4.  **Improved Namespace Management and Permissions:**
    *   **Description:** Kestra 1.1 brought more granular control over namespaces and the permissions associated with them. This allowed administrators to define more sophisticated access policies, ensuring that different teams or users only had access to the flows and resources relevant to them. This was a critical feature for security, governance, and multi-tenancy scenarios in larger organizations, preventing unauthorized access and conflicts.

5.  **Enhanced Flow Dependencies and Triggering:**
    *   **Description:** The ability to manage flow dependencies and advanced triggering mechanisms was significantly improved. This included more robust ways to trigger flows based on the completion of other flows (including success/failure states), external events, or file system changes. This made it easier to build complex data pipelines where one workflow's execution depends on the outcome of another, ensuring proper sequencing and reliable data processing.

🤔 Did you notice that this response seems to be:
- Incorrect?
- Vague/generic?
- Listing features that haven't been added in exactly this version but rather a long time ago?

👉 This is why context matters! Run `2_chat_with_rag.yaml` to see the accurate, context-grounded response.

```

# %%
```
INFO 2026-06-30T12:14:31.044483Z ✅ RAG Response (with retrieved context):
Kestra 1.1 introduced several major features. Here are at least 5 with brief descriptions:

1.  **New Filters**: The UI filters were completely redesigned to be more user-friendly, offering explicit filter options, a single-click reset, the ability to save frequently used filter combinations, and the option to hide, show, or reorder table columns.
2.  **No-Code Dashboard Editor**: This feature allows users to create and edit custom dashboards using a no-code, multi-panel editor directly from the UI, similar to the existing no-code flow editor.
3.  **Multi-Agent AI Systems**: AI agents can now utilize other AI agents as tools, enabling the creation of sophisticated multi-agent orchestration workflows where a primary agent can delegate subtasks to specialized expert agents.
4.  **Fix with AI**: When tasks fail, Kestra 1.1 provides AI-powered suggestions to help diagnose and resolve issues, offering intelligent recommendations for fixes.
5.  **Human Task**: For Enterprise Edition users, this feature introduces human-in-the-loop workflows where executions can be paused and require manual approval from specific users or groups before proceeding.
6.  **Improved Air-Gapped Support**: Kestra 1.1 significantly enhanced its support for offline and air-gapped environments, with the UI adapting to run without internet connectivity, fetching blueprints from the Kestra API, hiding external dependencies, and ensuring smooth operation in isolated setups.

🎉 Note that this response is detailed, accurate, and grounded in the actual release documentation. Compare this with the output from 1_chat_without_rag.yaml!

```

# %% [markdown]
# ## Q3 Token usage, short summary

# %%
```
INFO 2026-06-30T12:17:58.820447Z 📊 Token Usage Summary:

Multilingual Agent:
- Input tokens: 282
- Output tokens: 81
- Total tokens: 363

English Brevity Agent:
- Input tokens: 96
- Output tokens: 48
- Total tokens: 144

💡 Tip: Monitor token usage to understand costs and optimize prompts!

```

# %% [markdown]
# ## Q4 Token usage, long summary

# %%
```
INFO 2026-06-30T12:19:13.727154Z 📊 Token Usage Summary:

Multilingual Agent:
- Input tokens: 282
- Output tokens: 189
- Total tokens: 471

English Brevity Agent:
- Input tokens: 204
- Output tokens: 51
- Total tokens: 255

💡 Tip: Monitor token usage to understand costs and optimize prompts!

```

# %%
```
INFO 2026-06-30T12:28:47.642504Z 📊 Token Usage Summary:

Multilingual Agent:
- Input tokens: 282
- Output tokens: 184
- Total tokens: 466

English Brevity Agent:
- Input tokens: 199
- Output tokens: 35
- Total tokens: 234

💡 Tip: Monitor token usage to understand costs and optimize prompts!

```

# %% [markdown]
# ## Q5 Modifying a flow

# %%
```
INFO 2026-06-30T12:23:57.520484Z 📊 Token Usage Summary:

Multilingual Agent:
- Input tokens: 282
- Output tokens: 192
- Total tokens: 474

English Brevity Agent:
- Input tokens: 207
- Output tokens: 85
- Total tokens: 292

💡 Tip: Monitor token usage to understand costs and optimize prompts!

```
